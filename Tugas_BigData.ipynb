# %% [markdown]
# **TUGAS 1**

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34, "Senior Programmer", "Sepakbola","L"),
        ("Budi", 23, "Junior Programmer", "Memancing","L"),
        ("Citra", 29, "UI/UX Designer", "Membaca buku", "P"),
        ("Dina", 45, "IT Manager", "Jogging", "P")]
columns = ["Nama","Usia", "Pekerjaan", "Hobi", "Gender"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()
# Out:
# +-----+----+-----------------+------------+------+
# | Nama|Usia|        Pekerjaan|        Hobi|Gender|
# +-----+----+-----------------+------------+------+
# |  Ali|  34|Senior Programmer|   Sepakbola|     L|
# | Budi|  23|Junior Programmer|   Memancing|     L|
# |Citra|  29|   UI/UX Designer|Membaca buku|     P|
# | Dina|  45|       IT Manager|     Jogging|     P|
# +-----+----+-----------------+------------+------+

# %% [markdown]
# **TUGAS 2**

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34, "Senior Programmer", "Sepakbola","L"),
        ("Budi", 23, "Junior Programmer", "Memancing","L"),
        ("Citra", 29, "UI/UX Designer", "Membaca buku", "P"),
        ("Dina", 45, "IT Manager", "Jogging", "P")]
columns = ["Nama","Usia", "Pekerjaan", "Hobi", "Gender"]
df = spark.createDataFrame(data, columns)

# Filtering data
df_filtered = df.filter(df['Gender'] == 'L')
df_filtered.show()

# Menghitung rata-rata usia
df.groupBy().agg(avg("Usia")).show()

# Mengurutkan data berdasarkan usia
df_sorted = df.orderBy("Usia", ascending=True)
df_sorted.show()
# Out:
# +----+----+-----------------+---------+------+
# |Nama|Usia|        Pekerjaan|     Hobi|Gender|
# +----+----+-----------------+---------+------+
# | Ali|  34|Senior Programmer|Sepakbola|     L|
# |Budi|  23|Junior Programmer|Memancing|     L|
# +----+----+-----------------+---------+------+
#
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+
#
# +-----+----+-----------------+------------+------+
# | Nama|Usia|        Pekerjaan|        Hobi|Gender|
# +-----+----+-----------------+------------+------+
# | Budi|  23|Junior Programmer|   Memancing|     L|
# |Citra|  29|   UI/UX Designer|Membaca buku|     P|
# |  Ali|  34|Senior Programmer|   Sepakbola|     L|
# | Dina|  45|       IT Manager|     Jogging|     P|
# +-----+----+-----------------+------------+------+

# %% [markdown]
# **TUGAS 3**

# %%
import pandas as pd

# Membuat Datarame Pandas
data_pandas = {"Nama": ['Ali', 'Budi', 'Citra', 'Dina'],
               "Usia": [34, 23, 29, 45],
               "Gender": ["L", "L", "P", "P"],
               "Prodi": ["TI", "TE", "TI", "TE"],
               "Tahun masuk": [2024, 2024, 2024, 2025]}

df_pandas = pd.DataFrame(data_pandas)

df_filtered_3 = df_pandas[df_pandas['Usia'] > 30]
df_filtered_3
# Out:
#    Nama  Usia Gender Prodi  Tahun masuk
# 0   Ali    34      L    TI         2024
# 3  Dina    45      P    TE         2025

# %% [markdown]
# **TUGAS 4**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"],
               "Usia": [34, 23, 29, 45]
               }
df_pandas = pd.DataFrame(data_pandas)

# Membuat DataFrame kedua
data_pandas_2 = {"Nama": ["Ali", "Budi", "Citra", "Dina"],
                 "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]
                 }
df_pandas_2 = pd.DataFrame(data_pandas_2)

# Join antara dua DataFrame
df_joined = pd.merge(df_pandas, df_pandas_2, on='Nama')

# Plotting data
df_joined.plot(x='Nama', y='Usia', kind='bar', title='Usia')
plt.show()
df_joined
# Out:
#     Nama  Usia Pekerjaan
# 0    Ali    34    Dokter
# 1   Budi    23      Guru
# 2  Citra    29  Insinyur
# 3   Dina    45   Perawat

# %% [markdown]
# **TUGAS 5**

# %%
# Mengonnversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konnversi
df_pandas_from_spark, df_spark_from_pandas.show()

# Menghitung rata-rata usia
df.groupBy().agg(avg("Usia")).show()
# Out:
# +-----+----+------+-----+-----------+
# | Nama|Usia|Gender|Prodi|Tahun masuk|
# +-----+----+------+-----+-----------+
# |  Ali|  34|     L|   TI|       2024|
# | Budi|  23|     L|   TE|       2024|
# |Citra|  29|     P|   TI|       2024|
# | Dina|  45|     P|   TE|       2025|
# +-----+----+------+-----+-----------+
#
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+

# %% [markdown]
# **TUGAS 6**

# %%
# Mengonnversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konnversi
df_pandas_from_spark, df_spark_from_pandas.show()

# Menghitung rata-rata usia
from pyspark.sql.functions import max
df.groupBy().agg(max("Usia")).show()
# Out:
# +-----+----+------+-----+-----------+
# | Nama|Usia|Gender|Prodi|Tahun masuk|
# +-----+----+------+-----+-----------+
# |  Ali|  34|     L|   TI|       2024|
# | Budi|  23|     L|   TE|       2024|
# |Citra|  29|     P|   TI|       2024|
# | Dina|  45|     P|   TE|       2025|
# +-----+----+------+-----+-----------+
#
# +---------+
# |max(Usia)|
# +---------+
# |       45|
# +---------+
